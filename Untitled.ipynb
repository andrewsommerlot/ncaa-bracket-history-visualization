# %%
#===========================================================
# Visualizing the March Madness Basketball Turnament Results with datashader

# import 

from dask.distributed import Client, progress
import dask.dataframe as dd
from dask.distributed import progress

import distributed
print(distributed.__version__)

import numpy as np


import tornado
print(tornado.version)

import datashader as ds
import datashader.glyphs
import datashader.transfer_functions as tf

from bokeh.plotting import figure, output_notebook, show
from IPython.core.display import HTML, display
from bokeh.models import BoxZoomTool

output_notebook()

from datashader.bokeh_ext import InteractiveImage
from datashader.colors import Hot
#from datashader.colors import Cold
from colorcet import fire

from datashader.utils import export_image

import pandas as pd
# Out:
# 1.20.2
# 4.5.3
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f99c0d73-5ef8-42c1-a851-c11f64b8e38a">Loading BokehJS ...</span>
#     </div>

# %%
#====================================================
# read in the turnament data

# source: https://data.world/michaelaroy/ncaa-tournament-results/workspace/file?filename=Big_Dance_CSV.csv
df = dd.read_csv('/home/andrewrs/Desktop/github/march_madness/Big_Dance_CSV.csv', header = 0, sep= ',')  

df.head()
# Out:
#    Year  Round  Region_Number Region_Name  Seed1  Score1       Team1  \
# 0  1985      1              1        West      1      83    St Johns
# 1  1985      1              1        West      2      81         VCU
# 2  1985      1              1        West      3      65    NC State
# 3  1985      1              1        West      4      85        UNLV
# 4  1985      1              1        West      5      58  Washington
#
#           Team2  Score2  Seed2
# 0      Southern      59     16
# 1      Marshall      65     15
# 2        Nevada      56     14
# 3  San Diego St      80     13
# 4      Kentucky      65     12

# %%
#======================================================================
# build the vertices map for the lines  
#

# centered on zero zero, build by 5s and 10s middle is 20 i guess
# this makes 1 quarter of the bracket. 

# possible x's: 
x = [-60, -50, -40, -30, -20, -10]

# back up 5 for the national champ space 
x = [it-5 for it in x]

# possible y's 1st column
y1 = [-80, -70, -60, -50, -40, -30, -20, -10, 10, 20, 30, 40, 50, 60, 70, 80]

# possible y's second column
y2 = [-75, -55, -35, -15, 15, 35, 55, 75]

# possible y's second column
y3 = [-65, -25, 25, 65]

# possible y's for
y4 = [-45, 45]

y5 = [0]

# build the xy corrdinates

x_cord = [np.repeat(x[0], len(y1)).tolist(), \
          np.repeat(x[1], len(y1)).tolist(), \
          np.repeat(x[1], len(y2)).tolist(), \
          np.repeat(x[2], len(y2)).tolist(), \
          np.repeat(x[2], len(y3)).tolist(), \
          np.repeat(x[3], len(y3)).tolist(), \
          np.repeat(x[3], len(y4)).tolist(), \
          np.repeat(x[4], len(y4)).tolist(), \
          np.repeat(x[4], len(y5)).tolist(), \
          np.repeat(x[5], len(y5)).tolist()]

y_cord = [y1, y1, y2, y2, y3, y3, y4, y4, y5, y5]

# %%
#=======================================================
# unnest the points
y = [item for sublist in y_cord for item in sublist]
x = [item for sublist in x_cord for item in sublist]

# %%
#======================================================
# plot the bracket points with bokeh

from bokeh.plotting import figure, output_file, show

p = figure(plot_width=400, plot_height=400)

# make the glyph
p.circle(x, y, size = 4, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b2c500f5-58ae-4975-ac84-5927f35459bf"></div>
# </div>

# %%
#===================================================================
# now trasform to make 4 of them 
x_top_left = x
y_top_left = [it+100 for it in y]

# reflection 
x_top_right = [it*-1 for it in x]
y_top_right = y_top_left

x_bottom_left = x
y_bottom_left = [it-100 for it in y]

# reflection 
x_bottom_right = [it*-1 for it in x]
y_bottom_right = y_bottom_left

# %%
#===============================================
# look at top left
p = figure(plot_width=400, plot_height=400)

# make the glyph
p.circle(x_top_left, y_top_left, size = 4, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="54919212-737e-41ba-8739-81bafe5dfe56"></div>
# </div>

# %%
#===============================================
# look at top right 
p = figure(plot_width=400, plot_height=400)

# make the glyph
p.circle(x_top_right, y_top_right, size = 4, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d15019e8-029d-4429-a8b4-273aba6ec899"></div>
# </div>

# %%
#===============================================
# look at bottom left
p = figure(plot_width=400, plot_height=400)

# make the glyph
p.circle(x_bottom_left, y_bottom_left, size = 4, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="962405bc-93e3-447f-a3ea-2b09c3857f82"></div>
# </div>

# %%
#===============================================
# look at bottom right
p = figure(plot_width=400, plot_height=400)

# make the glyph
p.circle(x_bottom_right, y_bottom_right, size = 4, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="10d5f957-be0d-4278-883b-82d74a851951"></div>
# </div>

# %%
#==============================================================
# put it all together and get the winner location 

x_all = x_top_left + x_top_right + x_bottom_right + x_bottom_left
y_all = y_top_left + y_top_right + y_bottom_right + y_bottom_left

# %%
#=============================================================
# plot all 

#===============================================
# look at bottom right
p = figure(plot_width=400, plot_height=400)

# make the glyph
p.circle(x_all, y_all, size = 4, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="38cb58c9-6386-4bad-a07b-007080c587bf"></div>
# </div>

# %%
#================================================================
# now add one spot on the 1 and three position regions for the semi-final winner

# region 1 vs region 4 
x_all.append(-15)
x_all.append(-5)
y_all.append(0)
y_all.append(0)


# region 2 vs region 3 
x_all.append(15)
x_all.append(5)
y_all.append(0)
y_all.append(0)

# national champ 
# region 2 vs region 3 
x_all.append(-5)
x_all.append(5)
y_all.append(50)
y_all.append(50)

# %%
#=============================================================
# plot all with semi and national champ spots 

#===============================================
# look at bottom right
p = figure(plot_width=400, plot_height=400)

# make the glyph
p.circle(x_all, y_all, size = 4, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1b38d7d1-c9bd-4761-a816-64e0c3815b09"></div>
# </div>

# %%
#=============================================================
# scale out the x axis to make it look more like a regular bracket

x_all = [it*8 for it in x_all]

y_all = [it*2 for it in y_all]
#=============================================================
# plot all with semi and national champ spots 

#===============================================
# look at bottom right
p = figure(plot_width=800, plot_height=600)

# make the glyph
p.circle(x_all, y_all, size = 4, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="74598ac0-137c-4642-801a-2ddf8c1444b7"></div>
# </div>

# %%
#===============================================
# look at bottom right
from bokeh.models import HoverTool

hover = HoverTool(tooltips=[
    ("x", "$x"),
    ("y", "$y"),
])

p = figure(plot_width=800, plot_height=600, tools = [hover])

# make the glyph
p.circle(x_all, y_all, size = 5, color = 'navy', alpha = 1)

# show the frame 
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3b2e912f-3324-4eac-bfb4-9c8b62e2214a"></div>
# </div>

# %%
#==========================================================================
# define th 64 unique positional paths to the championship 

# they will be defined by x_RegionNumber_Seed 

# they should all be length 14 
# there is a bunch of structure repeating by each sub-octave 
# this can be coded out but, I can't think of it right now. 
# x's are the same for each 

# defines the path for each seed in region 1 to win the whole turnament
x1_1 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_1 = [360, 360, 350, 350, 330, 330, 290, 290, 200, 200, 0, 0, 50, 50]

x1_16 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_16 = [340, 340, 350, 350, 330, 330, 290, 290, 200, 200, 0, 0, 50, 50]

x1_8 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_8 = [320, 320, 310, 310, 330, 330, 290, 290, 200, 200, 0, 0, 50, 50]

x1_9 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_9 = [300, 300, 310, 310, 330, 330, 290, 290, 200, 200, 0, 0, 50, 50]

x1_5 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_5 = [280, 280, 270, 270, 250, 250, 290, 290, 200, 200, 0, 0, 50, 50]

x1_12 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_12 = [260, 260, 270, 270, 250, 250, 290, 290, 200, 200, 0, 0, 50, 50]

x1_4 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_4 = [240, 240, 230, 230, 250, 250, 290, 290, 200, 200, 0, 0, 50, 50]

x1_13 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_13 = [220, 220, 230, 230, 250, 250, 290, 290, 200, 200, 0, 0, 50, 50]

x1_6 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_6 = [180, 180, 170, 170, 150, 150, 110, 110, 200, 200, 0, 0, 50, 50]

x1_11 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_11 = [160, 160, 170, 170, 150, 150, 110, 110, 200, 200, 0, 0, 50, 50]

x1_3 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_3 = [140, 140, 130, 130, 150, 150, 110, 110, 200, 200, 0, 0, 50, 50]

x1_14 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_14 = [120, 120, 130, 130, 150, 150, 110, 110, 200, 200, 0, 0, 50, 50]

x1_7 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_7 = [100, 100, 90, 90, 70, 70, 110, 110, 200, 200, 0, 0, 50, 50]

x1_10 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_10 = [80, 80, 90, 90, 70, 70, 110, 110, 200, 200, 0, 0, 50, 50]

x1_2 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_2 = [60, 60, 50, 50, 70, 70, 110, 110, 200, 200, 0, 0, 50, 50]

x1_15 = [-520, -440, -440, -360, -360, -280, -280, -200, -200, -120, -120, -40, -40, 40]
y1_15 = [40, 40, 50, 50, 70, 70, 110, 110, 200, 200, 0, 0, 50, 50]

# make a numpy array of the x and ys from region 1 

r1_x_list = [x1_1, x1_2, x1_3, x1_4, x1_5, x1_6, x1_7, x1_8, x1_9, x1_10, x1_11, x1_12, x1_13, x1_14, x1_15, x1_16]
r1_y_list = [y1_1, y1_2, y1_3, y1_4, y1_5, y1_6, y1_7, y1_8, y1_9, y1_10, y1_11, y1_12, y1_13, y1_14, y1_15, y1_16]

r1_x = np.zeros([16, 14])
for i in range(0, 16):
    r1_x[i,:] = r1_x_list[i]
    
r1_y = np.zeros([16, 14])
for i in range(0, 16):
    r1_y[i,:] = r1_y_list[i]

# %%
#======================================================
# calcualte the rest of the region paths same a before, national champ is unchanged in each
# y and x expantion factors 
r1_y = r1_y * 1.75
r1_x = r1_x * 2

r4_y = np.copy(r1_y)
r4_y[:,0:10] = r4_y[:,0:10] - 400 * 1.75
r4_x = np.copy(r1_x)

r2_y = np.copy(r1_y)
r2_x = np.copy(r1_x) * -1

r3_y = np.copy(r2_y)
r3_y[:,0:10] = r2_y[:,0:10] - 400 * 1.75
r3_x = np.copy(r2_x)

# %%
#======================================================
# stack the regions up
# !! here, I've run into a problem. I'm not sure what the region numbers mean. 
#  I've researched it a bit, but I'm having trouble figuring out what the region numbers mean in the 
#  dataset, and how regions are used in general in the ncaa bracket process. lining them up clockwise from 1 to 4,
#  I found that the exhibited idential features to this article: 
#      https://www.foxsports.com/college-basketball/story/ncaa-tournament-bracket-history-which-seeds-regions-brackets-have-most-winners-2017-teams-can-win-031517
# But, in a functionally different order. In mine top right is 1, and 1 plays region 4, which sits below it. 
# On the top right is region 2 and three sits below it. Comparing my results with the article, It looks like my 
# Region 1 is the articles region 1, but, the others are different. In this relationship:

#  mine,  theirs 
#  1   ,  1
#  2   ,  4
#  3   ,  2
#  4,  ,  3 

# Meaning, in the dataset I'm using region 1 plays region 2, and region 3 plays region 4. My assumption was
#  the regions were like seeds, where 1 would play 4 and 2 would play 3. 

# So, I don't know how to organize these for sure. Here, I have it put so it corresponds to the fox sports article

x_lines = np.vstack([r1_x, r4_x, r2_x, r3_x])
y_lines = np.vstack([r1_y, r4_y, r2_y, r3_y])

# %%
jitter_x = 4
jitter_y = 4

import math

x_big = []
y_big = []
for i in range(0, 64):
    for it in x_lines[i,:].tolist():
        x_big.append(it+float(np.random.uniform(-jitter_x, jitter_x, 1)))
    x_big.append(math.nan)
    for it in y_lines[i,:].tolist():
        y_big.append(it+float(np.random.uniform(-jitter_y, jitter_y, 1)))
    y_big.append(math.nan)

# %%
#==========================================
# artificially more lines 
jitter_x = 3
jitter_y = 3
import math
x_big = []
y_big = []

for j in range(0, 1000):
    for i in range(0, 64):
        for it in x_lines[i,:].tolist():
            x_big.append(it+float(np.random.standard_t(10, 1)))
        x_big.append(math.nan)
        for it in y_lines[i,:].tolist():
            y_big.append(it+float(np.random.standard_t(10, 1)))
        y_big.append(math.nan)

# %%
import pandas as pd

# %%
both = pd.DataFrame(x_big)
both['y'] = y_big
both.columns = ['x', 'y']

# %%
type(both['x'][14])
# Out:
# numpy.float64

# %%
#==================================================================================
# some color palletes that dont start with black 
# heres the hot pallete 
Hot_orig = ["black", "maroon", "darkred", "red", "orangered", "darkorange", "orange", "gold", "yellow", "white"]

# palletes I got from a graphic design blog. 
# https://blog.graphiq.com/finding-the-right-color-palettes-for-data-visualizations-fcd4e707a283
# droppered them off a few pictures in that webpage 

cool = ['#000000', '#11174b', '#162065', '#1c2b7f', '#24448e', '#2d5e9e', '#3577ae', '#3d91be',  '#46aace', '#62bed2', '#8acdce', '#b3ddcc', '#dcecc9', '#ffffff']

neon = ['#000000', '#2d0f41', '#3d1459', '#4d1a70', '#5e1f88', '#742796', '#973490', '#b8428c',  '#db5087', '#e96a8d', '#ee8b97', '#f3aca2', '#f9cdac', '#ffffff']

hot = ['#000000', '#4c3430', '#753c2c', '#9d4429', '#c74e29', '#e35b2c', '#e77235', '#eb8a40',  '#f0a04b', '#f5b857', '#f9d063', '#fde86e', '#fded86', '#ffffff']

# %%
from colorcet import fire
short_fire = fire[:]

short_fire = [short_fire[i] for i in [42, 84, 126, 168, 210, 252]]

# %%
#=====================================================
# define the create image function
def create_image(df, x_range, y_range, w, h, cmap):
    cvs = ds.Canvas(plot_width=w, plot_height=h, x_range = x_range, y_range = y_range)
    agg = cvs.line(df, 'x', 'y', ds.count(), )
    return tf.shade(agg, cmap = cmap, how='eq_hist')

# %%
#=======================================================
# build the raw bracket image
test_img = create_image(both, x_range = (-650, 650), y_range = (-450, 450), w=1000, h=800, cmap=short_fire)
test_img = tf.dynspread(test_img, threshold = .1)

# %%
#=================================
# export the image 
export_image(tf.set_background(test_img, 'black'),'pics/bracket_test')
# Out:
# <xarray.Image (y: 800, x: 1000)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * y        (y) float64 -449.4 -448.3 -447.2 -446.1 -444.9 -443.8 -442.7 ...
#   * x        (x) float64 -649.3 -648.0 -646.8 -645.4 -644.1 -642.8 -641.5 ...

# %%
#======================================================
# now the data has to be used to dictate the lines which are drawn. 
# 1) a list of x and y's for lines origniating at the seed positions and terminating at the team 
#       in that positions loss 
# 2) increase the number of identical lines drawn by a multiple for each win  
# 3) apply jitter, which will make longer winning lines thicker and brighter after using data shader
# 4) Convert to pandas dataframe 
# 5) plot.

# %%
#===========================================================
# reading in the data 
#====================================================
# read in the turnament data

# source: https://data.world/michaelaroy/ncaa-tournament-results/workspace/file?filename=Big_Dance_CSV.csv
df = dd.read_csv('/home/andrewrs/Desktop/github/march_madness/Big_Dance_CSV.csv', header = 0, sep= ',')  

df.head()
# Out:
#    Year  Round  Region_Number Region_Name  Seed1  Score1       Team1  \
# 0  1985      1              1        West      1      83    St Johns
# 1  1985      1              1        West      2      81         VCU
# 2  1985      1              1        West      3      65    NC State
# 3  1985      1              1        West      4      85        UNLV
# 4  1985      1              1        West      5      58  Washington
#
#           Team2  Score2  Seed2
# 0      Southern      59     16
# 1      Marshall      65     15
# 2        Nevada      56     14
# 3  San Diego St      80     13
# 4      Kentucky      65     12

# %%
#==================================================
# make a map for the first year
df_1985 = df.loc[(df['Year'] == 1985),:]

df.head()
# Out:
#    Year  Round  Region_Number Region_Name  Seed1  Score1       Team1  \
# 0  1985      1              1        West      1      83    St Johns
# 1  1985      1              1        West      2      81         VCU
# 2  1985      1              1        West      3      65    NC State
# 3  1985      1              1        West      4      85        UNLV
# 4  1985      1              1        West      5      58  Washington
#
#           Team2  Score2  Seed2
# 0      Southern      59     16
# 1      Marshall      65     15
# 2        Nevada      56     14
# 3  San Diego St      80     13
# 4      Kentucky      65     12

# %%
#========================================================
# each team must be matched to their region_seed position

region = [1,2,3,4] * 16
seed = np.repeat(np.linspace(1, 16, 16), 4)

lookup = pd.DataFrame(region)
lookup[1] = seed
lookup.columns = ['region', 'seed']

# %%
lookup
# Out:
#     region  seed
# 0        1   1.0
# 1        2   1.0
# 2        3   1.0
# 3        4   1.0
# 4        1   2.0
# 5        2   2.0
# 6        3   2.0
# 7        4   2.0
# 8        1   3.0
# 9        2   3.0
# 10       3   3.0
# 11       4   3.0
# 12       1   4.0
# 13       2   4.0
# 14       3   4.0
# 15       4   4.0
# 16       1   5.0
# 17       2   5.0
# 18       3   5.0
# 19       4   5.0
# 20       1   6.0
# 21       2   6.0
# 22       3   6.0
# 23       4   6.0
# 24       1   7.0
# 25       2   7.0
# 26       3   7.0
# 27       4   7.0
# 28       1   8.0
# 29       2   8.0
# ..     ...   ...
# 34       3   9.0
# 35       4   9.0
# 36       1  10.0
# 37       2  10.0
# 38       3  10.0
# 39       4  10.0
# 40       1  11.0
# 41       2  11.0
# 42       3  11.0
# 43       4  11.0
# 44       1  12.0
# 45       2  12.0
# 46       3  12.0
# 47       4  12.0
# 48       1  13.0
# 49       2  13.0
# 50       3  13.0
# 51       4  13.0
# 52       1  14.0
# 53       2  14.0
# 54       3  14.0
# 55       4  14.0
# 56       1  15.0
# 57       2  15.0
# 58       3  15.0
# 59       4  15.0
# 60       1  16.0
# 61       2  16.0
# 62       3  16.0
# 63       4  16.0
#
# [64 rows x 2 columns]

# %%
#==========================================================================================
# match team to region seed position

a_data = pd.read_csv('/home/andrewrs/Desktop/github/march_madness/Big_Dance_CSV.csv')
b_data = b_data.loc[(b_data['Year'] == 1985),:]

# %%
b_data.head()
# Out:
#    Year  Round  Region_Number Region_Name  Seed1  Score1       Team1  \
# 0  1985      1              1        West      1      83    St Johns
# 1  1985      1              1        West      2      81         VCU
# 2  1985      1              1        West      3      65    NC State
# 3  1985      1              1        West      4      85        UNLV
# 4  1985      1              1        West      5      58  Washington
#
#           Team2  Score2  Seed2
# 0      Southern      59     16
# 1      Marshall      65     15
# 2        Nevada      56     14
# 3  San Diego St      80     13
# 4      Kentucky      65     12

# %%
#==============================================
# get 3 column dataframe region number, seed, team name, for the year 
# no need for joins and things here yet I think


region_number = b_data['Region_Number'].append(b_data['Region_Number'])

seed = b_data['Seed1'].append(b_data['Seed2'])

team = b_data['Team1'].append(b_data['Team2'])

lookup = pd.DataFrame(region_number)
lookup[1] = seed
lookup[2] = team
lookup.columns = ['region', 'seed', 'team']

# needs assignment
lookup = lookup.drop_duplicates(subset = ['region', 'seed'], keep='first')

len(lookup)

#lookup.merge(b_data, left_on = ['region', 'seed'], right_on = ['Region_Number','Seed1' ])
# Out:
# 64

# %%
#=====================================================
# Now team names correspond to region-positions, which correspond to 
#     unique geometric paths to the championship defined eariler
# now I need the length of each team path defined through "win-steps"
# I'll try this by searching for the number of times the team is listed, which will work until the championship
# one minus this number is the number of point pairs, or win steps to light up. 

all_teams = lookup['team']

wins = []

for team in all_teams:

    sub = b_data.loc[(b_data['Team1'] == team),:]
    sub2 = b_data.loc[(b_data['Team2'] == team),:]

    # check both sides 
    max_round1 = sub['Round'].max()
    max_round2 = sub2['Round'].max()
    
    if math.isnan(max_round1):
        max_round1 = 0
    if math.isnan(max_round2):
        max_round2 = 0

    # get the total max
    max_round = np.max([max_round1, max_round2])

    if max_round == 6:
        champ_game = b_data.loc[(b_data['Round'] == 6),:]

        if champ_game['Team1'].item() == team:
            if champ_game['Score1'].item() > champ_game['Score2'].item():
                max_round = 7
            elif champ_game['Score2'].item() > champ_game['Score1'].item():
                max_round = 6
        if champ_game['Team2'].item() == team:
            if champ_game['Score2'].item() > champ_game['Score1'].item():
                max_round = 7
            elif champ_game['Score1'].item() > champ_game['Score2'].item():
                max_round = 6 
    else:
        max_round = max_round
    number_of_wins = max_round - 1
    wins.append(number_of_wins)

lookup['wins'] = wins

# %%
lookup
# Out:
#     region  seed                 team  wins
# 0        1     1             St Johns     4
# 1        1     2                  VCU     1
# 2        1     3             NC State     3
# 3        1     4                 UNLV     1
# 4        1     5           Washington     0
# 5        1     6                Tulsa     0
# 6        1     7              Alabama     2
# 7        1     8                 Iowa     0
# 8        2     1           Georgetown     5
# 9        2     2         Georgia Tech     3
# 10       2     3             Illinois     2
# 11       2     4      Loyola Illinois     2
# 12       2     5                  SMU     1
# 13       2     6              Georgia     1
# 14       2     7             Syracuse     1
# 15       2     8               Temple     1
# 16       3     1             Oklahoma     3
# 17       3     2              Memphis     4
# 18       3     3                 Duke     1
# 19       3     4              Ohio St     1
# 20       3     5       Louisiana Tech     2
# 21       3     6           Texas Tech     0
# 22       3     7                  UAB     1
# 23       3     8                  USC     0
# 24       4     1             Michigan     1
# 25       4     2       North Carolina     3
# 26       4     3               Kansas     1
# 27       4     4                  LSU     0
# 28       4     5             Maryland     2
# 29       4     6               Purdue     0
# ..     ...   ...                  ...   ...
# 1        1    15             Marshall     0
# 2        1    14               Nevada     0
# 3        1    13         San Diego St     0
# 4        1    12             Kentucky     2
# 5        1    11                 UTEP     1
# 6        1    10              Arizona     0
# 7        1     9             Arkansas     1
# 8        2    16               Lehigh     0
# 9        2    15               Mercer     0
# 10       2    14         Northeastern     0
# 11       2    13                 Iona     0
# 12       2    12         Old Dominion     0
# 13       2    11           Wichita St     0
# 14       2    10               DePaul     0
# 15       2     9        Virginia Tech     0
# 16       3    16   North Carolina A&T     0
# 17       3    15         Pennsylvania     0
# 18       3    14           Pepperdine     0
# 19       3    13              Iowa St     0
# 20       3    12           Pittsburgh     0
# 21       3    11       Boston College     2
# 22       3    10          Michigan St     0
# 23       3     9          Illinois St     1
# 24       4    16  Fairleigh Dickinson     0
# 25       4    15  Middle Tennessee St     0
# 26       4    14                 Ohio     0
# 28       4    12           Miami Ohio     0
# 29       4    11               Auburn     2
# 30       4    10            Oregon St     0
# 31       4     9               Dayton     0
#
# [64 rows x 4 columns]

# %%
#==========================================
# define line points dependent on number of wins
# length has to include the connector, so they will all be odd, except the last 
def length_index(wins):
    ll = 2 + (wins*2) + 1
    if ll > 14:
        ll = 14
    return ll

# defines xy index based on the way the x and y line geometeries were desiged and stored
def xy_index(region, seed):
    xy_index = (((region - 1)*16) + seed) - 1
    return xy_index

# repeating lines: scale true paths linearly
def repeater_true(wins, multi = 100, base = 1):
    if wins == 0:
        lr = base    
    else:
        lr = (wins+1)*multi
    return lr

# repeating lines
def repeater_highlight(wins, multi = 1000, base = 2):
    if wins == 0:
        lr = base
    elif wins == 5:
        lr = wins*(multi**2)
    elif wins == 6:
        lr = wins*(multi**3)    
    else:
        lr = wins*multi
    return lr


def jitter_val(jitter = 5, df = 10):
    jv = float(np.random.standard_t(10, 1))
    if jv > jitter:
        jv = jitter
    if jv < -jitter:
        jv = -jitter
    return jv

# %%
#=============================================================
# create win paths for each team in each year uniquely by applying a partial region seed position path 
# Also, multiplicative increase in number of lines drawn to represent win path based on how many wins
# This is what the heatmap will be aggregating later 
#       (experiment with the number of lines increase and the jitter hyperparameters and jitter disribution)


jitter_x = 4
jitter_y = 4

import math

# Must length (number of points) depends on number of wins
x_big = []
y_big = []

# for loops for filling in all the lines based on the data. This is still just one year
#     needs to be built into a for loop including each year. 
for region, seed, wins, in zip(lookup['region'], lookup['seed'], lookup['wins']):
    # get length and line position indecies
    li = length_index(wins)
    xyi = xy_index(region, seed)
    rep_lines = line_repeater(wins)
    
    for i in range(0, rep_lines):
        for it in x_lines[xyi,0:li].tolist():
            x_big.append(it + float(np.random.standard_t(10, 1)))
        x_big.append(math.nan)
    
    for i in range(0, rep_lines):
        for it in y_lines[xyi,:li].tolist():
            y_big.append(it + float(np.random.standard_t(10, 1)))
        y_big.append(math.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-602a98b346f0> in <module>()
#      17 # for loops for filling in all the lines based on the data. This is still just one year
#      18 #     needs to be built into a for loop including each year.
# ---> 19 for region, seed, wins, in zip(lookup['region'], lookup['seed'], lookup['wins']):
#      20     # get length and line position indecies
#      21     li = length_index(wins)
#
# NameError: name 'lookup' is not defined

# %%
both = pd.DataFrame(x_big)
both['y'] = y_big
both.columns = ['x', 'y']

# %%
both
# Out:
#                  x           y
# 0      -518.721653  359.512515
# 1      -438.303831  359.879452
# 2      -440.330083  348.317224
# 3      -360.056039  348.926266
# 4      -358.280885  328.299650
# 5      -280.583813  327.047539
# 6      -279.075665  289.453399
# 7      -199.948818  291.546821
# 8      -197.754174  202.979365
# 9      -119.948988  199.338766
# 10     -121.979548    0.426124
# 11             NaN         NaN
# 12     -520.056169  359.251052
# 13     -438.999204  359.927651
# 14     -439.814940  348.056906
# 15     -359.438796  350.355826
# 16     -360.323731  330.034540
# 17     -281.222405  329.260787
# 18     -278.126647  289.605656
# 19     -198.691141  291.391673
# 20     -200.610370  201.188120
# 21     -121.228533  200.558695
# 22     -118.976187   -1.015997
# 23             NaN         NaN
# 24     -518.610216  359.259496
# 25     -439.282761  360.148278
# 26     -439.539377  349.663639
# 27     -359.070072  350.909315
# 28     -360.309688  331.878764
# 29     -280.663913  333.101402
# ...            ...         ...
# 600226 -441.569823 -230.791723
# 600227 -360.311323 -230.712596
# 600228 -359.926698 -249.041264
# 600229 -278.667142 -251.349748
# 600230 -281.245495 -289.791105
# 600231         NaN         NaN
# 600232 -521.343658 -237.654131
# 600233 -438.175296 -240.248526
# 600234 -438.997045 -229.052725
# 600235 -360.243429 -230.512058
# 600236 -359.393038 -250.601486
# 600237 -277.788180 -250.369853
# 600238 -280.006464 -289.838211
# 600239         NaN         NaN
# 600240 -519.850556 -321.338542
# 600241 -440.797497 -320.405361
# 600242 -439.826249 -310.201933
# 600243         NaN         NaN
# 600244 -522.065194 -319.724425
# 600245 -439.698524 -318.924134
# 600246 -439.941634 -310.695630
# 600247         NaN         NaN
# 600248 -520.954386 -100.082208
# 600249 -441.148363  -99.820635
# 600250 -440.603245  -89.454086
# 600251         NaN         NaN
# 600252 -520.158916  -98.712423
# 600253 -439.916636  -99.267046
# 600254 -440.550332  -90.251604
# 600255         NaN         NaN
#
# [600256 rows x 2 columns]

# %%
#=====================================================
# define the create image function
def create_image(df, x_range, y_range, w, h, cmap):
    cvs = ds.Canvas(plot_width=w, plot_height=h, x_range = x_range, y_range = y_range)
    agg = cvs.line(df, 'x', 'y', ds.count(), )
    return tf.shade(agg, cmap = cmap, how='eq_hist')

# %%
#=======================================================
# build the raw bracket image
test_img = create_image(both, x_range = (-650, 650), y_range = (-450, 450), w=1000, h=800, cmap = fire)
test_img = tf.dynspread(test_img, threshold = .1)

# %%
#=================================
# export the image 
export_image(tf.set_background(test_img, 'black'),'pics/1985')
# Out:
# <xarray.Image (y: 800, x: 1000)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * y        (y) float64 -449.4 -448.3 -447.2 -446.1 -444.9 -443.8 -442.7 ...
#   * x        (x) float64 -649.3 -648.0 -646.8 -645.4 -644.1 -642.8 -641.5 ...

# %%
#======================================================
# double check 
# after a bit of goofing, we see the 8 seed in region 4 won the turnament in 1985, paying against the 1 seed 
#    from region 2. Does the data table reflect this?   

# Yes! Villanova, an 8 seed beat Georgetown, a 1 seed
champ_game = b_data.loc[(b_data['Round'] == 6),:]
champ_game
# Out:
#     Year  Round  Region_Number   Region_Name  Seed1  Score1       Team1  \
# 62  1985      6              1  Championship      1      64  Georgetown
#
#         Team2  Score2  Seed2
# 62  Villanova      66      8

# %%
import math

# %%
#============================================================================
# now loop the whole thing for every year and build the table of lines. 

# re-read all data
a_data = pd.read_csv('/home/andrewrs/Desktop/github/march_madness/Big_Dance_CSV.csv')


# hyper parameters for the plot 
jitter_x = 10
jitter_y = 10
deg_free = 1
multi = 1
base = 1

# Must length (number of points) depends on number of wins
x_big = []
y_big = []

years = [it for it in a_data['Year'].drop_duplicates()]

for year in years:
    # get one turnament at a time
    b_data = a_data.loc[(a_data['Year'] == year),:]
    
    # build year-specific lookup table 
    region_number = b_data['Region_Number'].append(b_data['Region_Number'])
    seed = b_data['Seed1'].append(b_data['Seed2'])
    team = b_data['Team1'].append(b_data['Team2'])
    lookup = pd.DataFrame(region_number)
    lookup[1] = seed
    lookup[2] = team
    lookup.columns = ['region', 'seed', 'team']
    lookup = lookup.drop_duplicates(subset = ['region', 'seed'], keep='first')
    
    # add number of wins column to lookup table
    all_teams = lookup['team']
    wins = []
    for team in all_teams:
        sub = b_data.loc[(b_data['Team1'] == team),:]
        sub2 = b_data.loc[(b_data['Team2'] == team),:]
        max_round1 = sub['Round'].max()
        max_round2 = sub2['Round'].max()
        if math.isnan(max_round1):
            max_round1 = 0
        if math.isnan(max_round2):
            max_round2 = 0
        max_round = np.max([max_round1, max_round2])
        if max_round == 6:
            champ_game = b_data.loc[(b_data['Round'] == 6),:]
            if champ_game['Team1'].item() == team:
                if champ_game['Score1'].item() > champ_game['Score2'].item():
                    max_round = 7
                elif champ_game['Score2'].item() > champ_game['Score1'].item():
                    max_round = 6
            if champ_game['Team2'].item() == team:
                if champ_game['Score2'].item() > champ_game['Score1'].item():
                    max_round = 7
                elif champ_game['Score1'].item() > champ_game['Score2'].item():
                    max_round = 6 
        else:
            max_round = max_round
        number_of_wins = max_round - 1
        wins.append(number_of_wins)
    lookup['wins'] = wins
    
    # Write out the lines 
    for region, seed, wins, in zip(lookup['region'], lookup['seed'], lookup['wins']):
        li = length_index(wins)
        xyi = xy_index(region, seed)
        rep_lines = repeater_true(wins, multi = multi, base = base)
        for i in range(0, rep_lines):
            for it in x_lines[xyi,0:li].tolist():
                x_big.append(it + jitter_val(jitter = jitter_x, df = deg_free))
            x_big.append(math.nan)
        for i in range(0, rep_lines):
            for it in y_lines[xyi,:li].tolist():
                y_big.append(it + jitter_val(jitter = jitter_y, df = deg_free))
            y_big.append(math.nan)

# make pandas df for datashader plot of all years 
both = pd.DataFrame(x_big)
both['y'] = y_big
both.columns = ['x', 'y']

# %%
#=====================================================
# define the create image function
def create_image(df, x_range, y_range, w, h, cmap):
    cvs = ds.Canvas(plot_width=w, plot_height=h, x_range = x_range, y_range = y_range)
    agg = cvs.line(df, 'x', 'y', ds.count(), )
    return tf.shade(agg, cmap = cmap, how='eq_hist')

# %%
#=======================================================
# build the raw bracket image
#fire[26:len(fire)]


test_img = create_image(both, x_range = (-1200, 1200), y_range = (-700, 700), w=1400, h=800, cmap = fire)
test_img = tf.dynspread(test_img, threshold = 0)

# %%
#=================================
# export the image 
export_image(tf.set_background(test_img, 'black'),'pics/1985-2017_extra_true_lines')
# Out:
# <xarray.Image (y: 800, x: 1400)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * y        (y) float64 -699.1 -697.4 -695.6 -693.9 -692.1 -690.4 -688.6 ...
#   * x        (x) float64 -1.199e+03 -1.197e+03 -1.196e+03 -1.194e+03 ...

# %%
#=========================================================================
# with tweaks, the bracket can be drawn in many ways
# here it is with no repeats, all line are "true paths" that an actual team took.

#============================================================================
# now loop the whole thing for every year and build the table of lines. 

# re-read all data
a_data = pd.read_csv('/home/andrewrs/Desktop/github/march_madness/Big_Dance_CSV.csv')


# hyper parameters for the plot 
jitter_x = 0
jitter_y = 0
deg_free = 10
multi = 1
base = 1

# Must length (number of points) depends on number of wins
x_big = []
y_big = []

years = [it for it in a_data['Year'].drop_duplicates()]

for year in years:
    # get one turnament at a time
    b_data = a_data.loc[(a_data['Year'] == year),:]
    
    # build year-specific lookup table 
    region_number = b_data['Region_Number'].append(b_data['Region_Number'])
    seed = b_data['Seed1'].append(b_data['Seed2'])
    team = b_data['Team1'].append(b_data['Team2'])
    lookup = pd.DataFrame(region_number)
    lookup[1] = seed
    lookup[2] = team
    lookup.columns = ['region', 'seed', 'team']
    lookup = lookup.drop_duplicates(subset = ['region', 'seed'], keep='first')
    
    # add number of wins column to lookup table
    all_teams = lookup['team']
    wins = []
    for team in all_teams:
        sub = b_data.loc[(b_data['Team1'] == team),:]
        sub2 = b_data.loc[(b_data['Team2'] == team),:]
        max_round1 = sub['Round'].max()
        max_round2 = sub2['Round'].max()
        if math.isnan(max_round1):
            max_round1 = 0
        if math.isnan(max_round2):
            max_round2 = 0
        max_round = np.max([max_round1, max_round2])
        if max_round == 6:
            champ_game = b_data.loc[(b_data['Round'] == 6),:]
            if champ_game['Team1'].item() == team:
                if champ_game['Score1'].item() > champ_game['Score2'].item():
                    max_round = 7
                elif champ_game['Score2'].item() > champ_game['Score1'].item():
                    max_round = 6
            if champ_game['Team2'].item() == team:
                if champ_game['Score2'].item() > champ_game['Score1'].item():
                    max_round = 7
                elif champ_game['Score1'].item() > champ_game['Score2'].item():
                    max_round = 6 
        else:
            max_round = max_round
        number_of_wins = max_round - 1
        wins.append(number_of_wins)
    lookup['wins'] = wins
    
    # Write out the lines 
    for region, seed, wins, in zip(lookup['region'], lookup['seed'], lookup['wins']):
        li = length_index(wins)
        xyi = xy_index(region, seed)
        rep_lines = line_repeater(wins, multi = multi, base = base)
        for i in range(0, rep_lines):
            for it in x_lines[xyi,0:li].tolist():
                x_big.append(it + jitter_val(jitter = jitter_x, df = deg_free))
            x_big.append(math.nan)
        for i in range(0, rep_lines):
            for it in y_lines[xyi,:li].tolist():
                y_big.append(it + jitter_val(jitter = jitter_y, df = deg_free))
            y_big.append(math.nan)

# make pandas df for datashader plot of all years 
both = pd.DataFrame(x_big)
both['y'] = y_big
both.columns = ['x', 'y']

# %%
#=====================================================
# define the create image function
def create_image(df, x_range, y_range, w, h, cmap):
    cvs = ds.Canvas(plot_width=w, plot_height=h, x_range = x_range, y_range = y_range)
    agg = cvs.line(df, 'x', 'y', ds.count(), )
    return tf.shade(agg, cmap = cmap, how='eq_hist')

# %%
#=======================================================
# build the raw bracket image
test_img = create_image(both, x_range = (-1200, 1200), y_range = (-700, 700), w=1400, h=800, cmap = fire[10:len(fire)])
test_img = tf.dynspread(test_img, threshold = .8)

# export
export_image(tf.set_background(test_img, 'black'),'pics/1985-2017_true_paths_hist')
# Out:
# <xarray.Image (y: 800, x: 1400)>
# array([[4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        ...,
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080],
#        [4278190080, 4278190080, 4278190080, ..., 4278190080, 4278190080,
#         4278190080]], dtype=uint32)
# Coordinates:
#   * y        (y) float64 -699.1 -697.4 -695.6 -693.9 -692.1 -690.4 -688.6 ...
#   * x        (x) float64 -1.199e+03 -1.197e+03 -1.196e+03 -1.194e+03 ...
